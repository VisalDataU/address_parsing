# %%
import pandas as pd
from functions_package.predict import address_parser
# Out:
# /home/visal/anaconda3/envs/keras/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/visal/anaconda3/envs/keras/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/visal/anaconda3/envs/keras/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
df = pd.read_excel("./test_predictions/z1_cloud_address_66K.xlsx")
data = df.sample(n=10).reset_index(drop=True)

# %%
data = address_parser(data, "title_address")
# Out:
# 2022-09-20 16:15:18.433621: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally

# %%
data
# Out:
#                                        title_address  \
# 0  St.01, Stueng Slout, Neak Loeang, Peam Ro, Pre...
# 1  Phum Ta Saeng Kandal, Khum Ronak Ser, Srok San...
# 2  St.Samroung Andet, Kouk Khleang, Saensokh, Phn...
# 3  #, St.Street Concrete, Kat Phluk, Basedth, Kam...
# 4  Andoung, Mesar Prachan, Pea Reang, Prey Veng P...
# 5  #Located at Phum Prey Takae, St.Sangkat Boeng ...
# 6  217, Sangkat Veal Vong, Khan Prampir Meakkakra...
# 7  Banla S'et, Trapeang Sdau, Romeas Haek, Svay R...
# 8  #900, St.Lum, Thma Koul 1, Chaom Chau 2, Pur S...
# 9  #, St.Rubber Road, Ou Chrov, Boeng Preav, Srae...
#
#                 parsed_house_no  parsed_street_no parsed_borey  \
# 0
# 1
# 2
# 3                                Street Concrete
# 4
# 5  #Located at Phum Prey Takae
# 6                                            217
# 7
# 8                         #900
# 9
#
#   parsed_province    parsed_district parsed_commune   parsed_village  \
# ...
